# %%
import pandas as pd
import numpy as np

np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[0, 2] = np.nan

# %%
df.style.highlight_null().render().split('\n')[:10]
# Out:
# ['',
#  '        <style  type="text/css" >',
#  '        ',
#  '        ',
#  '            #T_6d59c17a_21c1_11e6_95a3_e0b9a51ef5d4row0_col2 {',
#  '            ',
#  '                background-color:  red;',
#  '            ',
#  '            }',
#  '        ']

# %%
def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if val < 0 else 'black'
    return 'color: %s' % color

# %%
s = df.style.applymap(color_negative_red)
s
# Out:
#         <style  type="text/css" >
#
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row0_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row0_col1 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row0_col2 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row0_col3 {
#
#                 color:  red;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row0_col4 {
#
#                 color:  red;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row1_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row1_col1 {
#
#                 color:  red;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row1_col2 {
#
#                 color:  red;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row1_col3 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row1_col4 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row2_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row2_col1 {
#
#                 color:  red;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row2_col2 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row2_col3 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row2_col4 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row3_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row3_col1 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row3_col2 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row3_col3 {
#
#                 color:  red;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row3_col4 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row4_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row4_col1 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row4_col2 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row4_col3 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row4_col4 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row5_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row5_col1 {
#
#                 color:  red;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row5_col2 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row5_col3 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row5_col4 {
#
#                 color:  red;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row6_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row6_col1 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row6_col2 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row6_col3 {
#
#                 color:  red;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row6_col4 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row7_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row7_col1 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row7_col2 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row7_col3 {
#
#                 color:  red;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row7_col4 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row8_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row8_col1 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row8_col2 {
#
#                 color:  red;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row8_col3 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row8_col4 {
#
#                 color:  red;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row9_col0 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row9_col1 {
#
#                 color:  red;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row9_col2 {
#
#                 color:  black;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row9_col3 {
#
#                 color:  red;
#
#             }
#
#             #T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4row9_col4 {
#
#                 color:  black;
#
#             }
#
#         </style>
#
#         <table id="T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4" None>
#
#
#         <thead>
#
#             <tr>
#
#                 <th class="blank">
#
#                 <th class="col_heading level0 col0">A
#
#                 <th class="col_heading level0 col1">B
#
#                 <th class="col_heading level0 col2">C
#
#                 <th class="col_heading level0 col3">D
#
#                 <th class="col_heading level0 col4">E
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#                 <th id="T_7ada7cc2_21c1_11e6_95a3_e0b9a51ef5d4" class="row_heading level4 row0">
#                     0
