# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn as sl
import sys

import matplotlib
matplotlib.style.use('ggplot')

# %matplotlib inline

# %%
data = pd.read_csv('data/breast_cancer.csv', header=None)
data.loc()[:, :].head() # just for test
# Out:
#          0  1      2      3       4       5        6        7       8   \
# 0    842302  M  17.99  10.38  122.80  1001.0  0.11840  0.27760  0.3001
# 1    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 2  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 3  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 4  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
#
#         9    ...        22     23      24      25      26      27      28  \
# 0  0.14710   ...     25.38  17.33  184.60  2019.0  0.1622  0.6656  0.7119
# 1  0.07017   ...     24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416
# 2  0.12790   ...     23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504
# 3  0.10520   ...     14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869
# 4  0.10430   ...     22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000
#
#        29      30       31
# 0  0.2654  0.4601  0.11890
# 1  0.1860  0.2750  0.08902
# ...

# %%
data[2].hist()

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(data[[2, 3, 4]], figsize=(15, 10))
# correlated data!
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1ea58df400>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1ea55ca630>]], dtype=object)

# %%
# deleting correlated data
def color_correlated(val):
    color = 'red' if val > 0.85 else 'black'
    return 'color: %s' % color
cor = data.loc()[:,2:10].corr().abs().style.applymap(color_correlated)
cor
# Out:
#         <style  type="text/css" >
#
#
#             #T_f5bddff0_21c2_11e6_95a3_e0b9a51ef5d4row0_col0 {
#
#                 color:  red;
#
#             }
#
#             #T_f5bddff0_21c2_11e6_95a3_e0b9a51ef5d4row0_col1 {
#
#                 color:  black;
#
#             }
#
#             #T_f5bddff0_21c2_11e6_95a3_e0b9a51ef5d4row0_col2 {
#
#                 color:  red;
#
#             }
#
#             #T_f5bddff0_21c2_11e6_95a3_e0b9a51ef5d4row0_col3 {
#
#                 color:  red;
#
#             }
#
#             #T_f5bddff0_21c2_11e6_95a3_e0b9a51ef5d4row0_col4 {
#
#                 color:  black;
#
#             }
#
#             #T_f5bddff0_21c2_11e6_95a3_e0b9a51ef5d4row0_col5 {
#
#                 color:  black;
#
#             }
#
#             #T_f5bddff0_21c2_11e6_95a3_e0b9a51ef5d4row0_col6 {
#
#                 color:  black;
#
#             }
#
#             #T_f5bddff0_21c2_11e6_95a3_e0b9a51ef5d4row0_col7 {
#
#                 color:  black;
#
#             }
#
# ...
